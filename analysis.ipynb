# %%
import pandas as pd
import datetime

# %%
us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}

# %%
# to show all rows and columns 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# read the csv into a pandas dataframe
df = pd.read_csv('Data/Sample-Superstore.csv', encoding='windows-1254')
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
for x, data in df.groupby(["State"]):
    print(x, sum(data["Sales"]))
# Out:
# Alabama 19510.639999999992
# Arizona 35282.001
# Arkansas 11678.129999999997
# California 457687.631500001
# Colorado 32108.117999999995
# Connecticut 13384.356999999996
# Delaware 27451.068999999992
# District of Columbia 2865.0199999999995
# Florida 89473.708
# Georgia 49095.840000000004
# Idaho 4382.486000000002
# Illinois 80166.10099999986
# Indiana 53555.36
# Iowa 4579.759999999999
# Kansas 2914.31
# Kentucky 36591.74999999997
# Louisiana 9217.029999999999
# Maine 1270.5300000000002
# Maryland 23705.523
# Massachusetts 28634.433999999994
# Michigan 76269.61400000002
# Minnesota 29863.149999999994
# Mississippi 10771.34
# Missouri 22205.149999999998
# Montana 5589.351999999997
# Nebraska 7464.9299999999985
# Nevada 16729.102
# New Hampshire 7292.523999999999
# New Jersey 35764.31200000001
# New Mexico 4783.521999999999
# New York 310876.2709999998
# North Carolina 55603.16399999997
# North Dakota 919.91
# Ohio 78258.13599999993
# Oklahoma 19683.39
# Oregon 17431.14999999999
# ...

# %%
df["Unit_Price"] = round(df["Sales"] / df["Quantity"] / (1-df["Discount"]), 4)

# %%
most_used_product = None
most_used_count = 0

for pid, data in df.groupby("Product ID"):
    group_size = len(data)
    if group_size > most_used_count:
        most_used_product = pid
        most_used_count = group_size

print("Most frequently used Product_ID:", most_used_product)
print("Count:", most_used_count)
# Out:
# Most frequently used Product_ID: OFF-PA-10001970
# Count: 19

# %%
i = 0
for productID, data in df.groupby("Product ID"):
    if len(data["Product Name"].drop_duplicates()) > 1:
        for productName, data2 in data.groupby("Product Name"):
            #print(productID, min(data2["Order Date"]), max(data2["Order Date"]), productName)
            if len(data2["Unit_Price"].drop_duplicates()) > 1:
                print(productID)
        #     display(data[["Product ID", "Category", "Sub-Category", "Product Name", "Unit_Price"]].drop_duplicates())
        #     i += 1
#        break
print(i)
# Out:
# 0

# %%
i = 0
for productID, data in df.groupby("Product ID"):
    if len(data["Product Name"].drop_duplicates()) > 1:
        # print(productID)
        # display(data[["Product ID", "Category", "Sub-Category", "Product Name", "Unit_Price"]].drop_duplicates())
        i += 2
#        break
    else:
        i += 1
print(i)
# Out:
# 1894

# %%
i = 0
for x, data in df.groupby(["Category", "Sub-Category", "Unit_Price"]):
    i += 1

print(i)
# Out:
# 1374

# %%
display(df[(df["Product ID"] == "OFF-PA-10001970")]) #  & (df.Unit_Price == 35.44)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 350      351  CA-2016-129714 2016-09-01 2016-09-03     First Class
# 352      353  CA-2016-129714 2016-09-01 2016-09-03     First Class
# 411      412  CA-2017-117457 2017-12-08 2017-12-12  Standard Class
# 437      438  CA-2016-147375 2016-06-12 2016-06-14    Second Class
# 1071    1072  CA-2016-152814 2016-04-28 2016-05-02  Standard Class
# 1117    1118  CA-2015-142755 2015-09-04 2015-09-08  Standard Class
# 1191    1192  CA-2017-117212 2017-02-26 2017-02-28    Second Class
# 3663    3664  US-2017-129777 2017-07-03 2017-07-09  Standard Class
# 3850    3851  CA-2015-142377 2015-12-04 2015-12-09  Standard Class
# 3949    3950  CA-2016-119963 2016-11-18 2016-11-22  Standard Class
# 5282    5283  CA-2015-105158 2015-09-05 2015-09-10  Standard Class
# 6334    6335  CA-2014-133305 2014-07-11 2014-07-15  Standard Class
# 6508    6509  CA-2017-102197 2017-12-20 2017-12-26  Standard Class
# ...

# %%
print(df["Product ID"].value_counts().shape)
df["Product ID"].head()
df.head()
# Out:
# (1862,)
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %% [markdown]
# ## Global Superstore Data
# ### Contains 51290 lines with 24 columns (+ Market, Shipping Cost, Order Priority)
# ### Contains a additional sheet with 2033 returns

# %%
# read the csv into a pandas dataframe
df_g = pd.read_csv('Data/Global-Superstore-Orders.csv')
df_g['Order Date'] = pd.to_datetime(df_g['Order Date'])
df_g['Ship Date'] = pd.to_datetime(df_g['Ship Date'])

# %%
for x, data in df_g.groupby(["State"]):
    print(x, sum(data["Sales"]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12952\1361090034.py in <module>
#       1 for x, data in df_g.groupby(["State"]):
# ----> 2     print(x, sum(data["Sales"]))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
df_g["Sales"] = df_g["Sales"].str.replace(',', '.')
df_g = df_g.astype({'Sales': 'float64'})

for x, data in df_g.groupby(["State"]):
    print(x, sum(data["Sales"]))
# Out:
# 'Ajman 209.988
# 'Amman 7167.989999999999
# 'Asir 1603.5
# Abia 1064.124
# Abidjan 15525.360000000002
# Abruzzi 6723.750000000002
# Abuja Capital Territory 38.016
# Aceh 337.5057
# Acre 701.98
# Ad Dawhah 6049.799999999999
# Adamaoua 774.0899999999999
# Adamawa 186.111
# Adana 5463.720000000002
# Adiyaman 502.50000000000006
# Afyonkarahisar 43.104
# Aichi 1596.7200000000003
# Aksaray 110.19600000000001
# Akwa Ibom 281.403
# Al Asimah 1094.22
# Al Bahr Al Ahmar 2586.66
# Al Basrah 13257.210000000003
# Al Buhayrah 709.83
# Al Fayyum 1164.4200000000003
# Al Gharbiyah 6084.209999999999
# Al Hudaydah 78.97500000000001
# Al Iskandariyah 19899.390000000018
# Al Jawf 3165.84
# Al Madinah 4619.009999999998
# Al Marqab 67.74
# Al Minufiyah 311.25
# Al Minya 2968.620000000001
# Al Qadisiyah 4182.660000000001
# Al Qahirah 38439.780000000006
# Alabama 19510.64
# Alagoas 5677.994200000001
# Alajuela 962.852
# Alberta 6550.86
# Alger 9270.06
# Alibori 268.77000000000004
# Almaty 200.79899999999998
# ...

# %% [markdown]
# ## Different Categories
# * (base) cat Sample-Superstore.csv | head -n 36 | tail -n 1
#
# `35,CA-2017-107727,10/19/2017,10/23/2017,Second Class,MA-17560,Matt Abelman,Home Office,United States,Houston,Texas,77095,Central,OFF-PA-10000249,Office Supplies,Paper,Easy-staple paper,29.472,3,0.2,9.9468`
# * (base) cat Global-Superstore-Orders.csv | grep "United States" | sort -n | head -n 35 | tail -n 1
#
# `31331,CA-2017-MA17560140-43028,10/20/2017,10/24/2017,Second Class,MA-175601402,Matt Abelman,Home Office,77095,Houston,Texas,United States,Central US,USCA,OFF-FA-6129,Staples,Fasteners,Office Supplies,"29,472",3,"0,2","9,9468","3,5",Medium`

# %% [markdown]
# # TODO
# ## Different dates for orders in Sample- and Global!!! (1 day apart)
# ```
# (base) stefan@Zeph:/mnt/c/Users/Coding/Documents/Python Scripts/M1P5S1-SQL/Data$ cat Global-Superstore-Orders.csv | grep "United States" | grep "OFF-ST-6289" | grep 2014 | grep Mari
# 41009,CA-2014-MD17350140-41947,11/4/2014,11/9/2014,Standard Class,MD-173501406,Maribeth Dona,Consumer,19143,Philadelphia,Pennsylvania,United States,Eastern US,USCA,OFF-ST-6289,Tennsco Double-Tier Lockers,Storage,Office Supplies,"1080,096",6,"0,2","-94,5084","53,84",Medium
# (base) stefan@Zeph:/mnt/c/Users/Coding/Documents/Python Scripts/M1P5S1-SQL/Data$ cat Sample-Superstore.csv | grep ",Tennsco Double-Tier" | grep 2014
# 9713,CA-2014-114251,11/5/2014,11/10/2014,Standard Class,MD-17350,Maribeth Dona,Consumer,United States,Philadelphia,Pennsylvania,19143,East,OFF-ST-10003716,Office Supplies,Storage,Tennsco Double-Tier Lockers,1080.096,6,0.2,-94.5084
# ```

# %% [markdown]
# In the Global DataSet are no orders on February 29th in 2016 (which was leap year)
#
# In Sample DataSet there is no 31.12.2017?
#
# I checked the original Sample Dataset from Tableau (https://community.tableau.com/s/question/0D54T00000CWeX8SAL/sample-superstore-sales-excelxls) and there is also the 31.12.2017 missing and the first entry is on the 03.01.2014 - meanwhile in the Global data set the first day is the 04.01.2014 and there is also a 31.12.2017

# %%
serial_number = 42250
date = datetime.datetime(1899, 12, 30) + datetime.timedelta(days=serial_number)

formatted_date = date.strftime('%d/%m/%Y')

print(formatted_date)  # Output: 18/06/2017
# Out:
# 03/09/2015

# %% [markdown]
# ### Dates with no sold products

# %%
delta = 41640
for date, data in df_g.groupby("Order Date"):
    #print(data["Order ID"].first.split('-')[-1])
    id = [data["Order ID"]][0]
    last_element = int([id.split('-')[-1] for id in data["Order ID"]][0])
    new_date = datetime.datetime(1899, 12, 30) + datetime.timedelta(days=int(last_element))
    #print(date)


    if  last_element != delta:
        print(last_element, delta, date)
        delta = last_element

    if str(date) != str(new_date):
        print(id)
        print(last_element, date, "!=", date.strftime('%Y-%m-%m 00:00:00'))     
        break
    
    delta = delta + 1
# Out:
# 41691 41690 2014-02-21 00:00:00
# 41711 41710 2014-03-13 00:00:00
# 41718 41717 2014-03-20 00:00:00
# 41739 41738 2014-04-10 00:00:00
# 41746 41745 2014-04-17 00:00:00
# 41760 41759 2014-05-01 00:00:00
# 41788 41787 2014-05-29 00:00:00
# 41823 41822 2014-07-03 00:00:00
# 41830 41829 2014-07-10 00:00:00
# 41865 41864 2014-08-14 00:00:00
# 41879 41878 2014-08-28 00:00:00
# 41886 41885 2014-09-04 00:00:00
# 41935 41934 2014-10-23 00:00:00
# 41991 41990 2014-12-18 00:00:00
# 42005 42004 2015-01-01 00:00:00
# 42019 42018 2015-01-15 00:00:00
# 42061 42060 2015-02-26 00:00:00
# 42068 42067 2015-03-05 00:00:00
# 42082 42081 2015-03-19 00:00:00
# 42089 42088 2015-03-26 00:00:00
# 42103 42102 2015-04-09 00:00:00
# 42208 42207 2015-07-23 00:00:00
# 42418 42417 2016-02-18 00:00:00
# 42425 42424 2016-02-25 00:00:00
# 42430 42429 2016-03-01 00:00:00
# 42482 42481 2016-04-22 00:00:00
# 42489 42488 2016-04-29 00:00:00
# 42678 42677 2016-11-04 00:00:00
# 42769 42768 2017-02-03 00:00:00
# ...

# %% [markdown]
# ## Black Friday

# %% [markdown]
# Freitag, 28. November
# Black Friday 2014
#
# Freitag, 27. November
# Black Friday 2015
#
# Freitag, 25. November
# Black Friday 2016
#
# Freitag, 24. November
# Black Friday 2017

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# for year in range(2014,2018):
#     print(year)
#     grouped1_df = df[(df["Order Date"] >= str(year) + "-11-23") & (df["Order Date"] <= str(year) + "-11-29")].groupby('Order Date')["Quantity"].sum()
#     grouped2_df = df_g[(df_g["Country"] == "United States") & (df_g["Order Date"] >= str(year) + "-11-23") & (df_g["Order Date"] <= str(year) + "-11-29")].groupby('Order Date')["Quantity"].sum()

#     display(grouped1_df)
#     display(grouped2_df)

#     # Plot the graph
#     plt.figure(figsize=(10, 6))  # Set the size of the plot (optional)
#     grouped1_df.plot(kind='line')
#     grouped2_df.plot(kind='line')
#     plt.title('Order Count per Date')
#     plt.xlabel('Order Date')
#     plt.ylabel('Count')
#     plt.show()

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# for year in range(2014,2018):
#     print(year)
#     grouped1_df = df[(df["Order Date"] >= str(year) + "-01-01") & (df["Order Date"] <= str(year) + "-12-31")].groupby('Order Date')["Quantity"].sum()
#     grouped2_df = df_g[(df_g["Country"] == "United States") & (df_g["Order Date"] >= str(year) + "-01-01") & (df_g["Order Date"] <= str(year) + "-12-31")].groupby('Order Date')["Quantity"].sum()

#     #display(grouped1_df)
#     #display(grouped2_df)

#     # Plot the graph
#     plt.figure(figsize=(10, 6))  # Set the size of the plot (optional)
#     grouped1_df.plot(kind='line', label="Sample")
#     grouped2_df.plot(kind='line', label="Global")
#     plt.legend(loc="upper left")
#     plt.title('Order Count per Date')
#     plt.xlabel('Order Date')
#     plt.ylabel('Count')
#     plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


grouped1_df = df[(df["Order Date"] >= "2014-02-23") & (df["Order Date"] <= "2014-03-05")].groupby('Order Date')["Quantity"].sum()
grouped2_df = df_g[(df_g["Country"] == "United States") & (df_g["Order Date"] >= "2014-02-24") & (df_g["Order Date"] <= "2014-03-05")].groupby('Order Date')["Quantity"].sum()

print("Sample", grouped1_df)
print("Global", grouped2_df)

# Plot the graph
# plt.figure(figsize=(10, 6))  # Set the size of the plot (optional)
# grouped1_df.plot(kind='line')
# grouped2_df.plot(kind='line')
# plt.title('Dateshift 2014')
# plt.xlabel('Order Date')
# plt.ylabel('Count')
# plt.show()
# Out:
# Sample Order Date
# 2014-02-23     6
# 2014-02-24     7
# 2014-02-27     4
# 2014-03-01    40
# 2014-03-02    11
# 2014-03-03    35
# 2014-03-04     8
# 2014-03-05    16
# Name: Quantity, dtype: int64
# Global Order Date
# 2014-02-24     6
# 2014-02-25     7
# 2014-02-28    44
# 2014-03-01    11
# 2014-03-02    35
# 2014-03-03     8
# 2014-03-04    16
# Name: Quantity, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt


grouped1_df = df[(df["Order Date"] >= "2015-02-23") & (df["Order Date"] <= "2015-03-05")].groupby('Order Date')["Quantity"].sum()
grouped2_df = df_g[(df_g["Country"] == "United States") & (df_g["Order Date"] >= "2015-02-22") & (df_g["Order Date"] <= "2015-03-05")].groupby('Order Date')["Quantity"].sum()

print("Sample", grouped1_df)
print("Global", grouped2_df)

# Plot the graph
# plt.figure(figsize=(10, 6))  # Set the size of the plot (optional)
# grouped1_df.plot(kind='line')
# grouped2_df.plot(kind='line')
# plt.title('Dateshift 2015')
# plt.xlabel('Order Date')
# plt.ylabel('Count')
# plt.show()
# Out:
# Sample Order Date
# 2015-02-23     8
# 2015-02-25     5
# 2015-02-27    27
# 2015-02-28    10
# 2015-03-01    23
# 2015-03-02    10
# 2015-03-05    57
# Name: Quantity, dtype: int64
# Global Order Date
# 2015-02-22     8
# 2015-02-24     5
# 2015-02-26    27
# 2015-02-27    10
# 2015-02-28     9
# 2015-03-01    14
# 2015-03-02    10
# 2015-03-05    57
# Name: Quantity, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt


grouped1_df = df[(df["Order Date"] >= "2016-02-25") & (df["Order Date"] <= "2016-03-05")].groupby('Order Date')["Quantity"].sum()
grouped2_df = df_g[(df_g["Country"] == "United States") & (df_g["Order Date"] >= "2016-02-25") & (df_g["Order Date"] <= "2016-03-06")].groupby('Order Date')["Quantity"].sum()

print("Sample", grouped1_df)
print("Global", grouped2_df)

# Plot the graph
# plt.figure(figsize=(10, 6))  # Set the size of the plot (optional)
# grouped1_df.plot(kind='line')
# grouped2_df.plot(kind='line')
# plt.title('Dateshift 2016')
# plt.xlabel('Order Date')
# plt.ylabel('Count')
# plt.show()
# Out:
# Sample Order Date
# 2016-02-25     5
# 2016-02-27     8
# 2016-02-28     6
# 2016-02-29     7
# 2016-03-01    20
# 2016-03-03    59
# 2016-03-04    10
# 2016-03-05     4
# Name: Quantity, dtype: int64
# Global Order Date
# 2016-02-25     5
# 2016-02-27     8
# 2016-02-28     6
# 2016-03-01     7
# 2016-03-02    20
# 2016-03-04    59
# 2016-03-05    10
# 2016-03-06     4
# Name: Quantity, dtype: int64

# %%
# 5769, CA-2015-154900,          2/25/2015,3/1/2015,Standard Class,SS-20875,    Sung Shariari,Consumer,United States,Leominster,Massachusetts,1453,East,OFF-LA-10001641,Office Supplies,Labels,Avery 518,3.15,1,0,1.512
# 37066,CA-2015-SS20875140-42059,2/24/2015,3/1/2015,Standard Class,SS-208751406,Sung Shariari,Consumer,1453,Leominster,Massachusetts,United States,Eastern US,USCA,OFF-PA-3010,"Adams Telephone Message Book W/Dividers/Space For Phone Numbers, 5 1/4""X8 1/2"", 200/Messages",Paper,Office Supplies,"22,72",4,0,"10,224","1,69",Medium

# %%
df[df["Order Date"] == "2015-02-25"]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 5768    5769  CA-2015-154900 2015-02-25 2015-03-01  Standard Class
# 5769    5770  CA-2015-154900 2015-02-25 2015-03-01  Standard Class
#
#      Customer ID  Customer Name   Segment        Country        City  \
# 5768    SS-20875  Sung Shariari  Consumer  United States  Leominster
# 5769    SS-20875  Sung Shariari  Consumer  United States  Leominster
#
#               State  Postal Code Region       Product ID         Category  \
# 5768  Massachusetts         1453   East  OFF-LA-10001641  Office Supplies
# 5769  Massachusetts         1453   East  OFF-PA-10002377  Office Supplies
#
#      Sub-Category                                       Product Name  Sales  \
# 5768       Labels                                          Avery 518   3.15
# 5769        Paper  Adams Telephone Message Book W/Dividers/Space ...  22.72
#
#       Quantity  Discount  Profit
# 5768         1       0.0   1.512
# ...

# %%
df_g[(df_g["Order Date"] == "2015-02-27") & (df_g["Country"] == "United States") ]
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 48507   31526  US-2015-VD21670140-42062 2015-02-27 2015-03-04  Standard Class
# 48508   31525  US-2015-VD21670140-42062 2015-02-27 2015-03-04  Standard Class
#
#         Customer ID      Customer Name   Segment  Postal Code      City  \
# 48507  VD-216701408  Valerie Dominguez  Consumer      38401.0  Columbia
# 48508  VD-216701408  Valerie Dominguez  Consumer      38401.0  Columbia
#
#            State        Country       Region Market   Product ID  \
# 48507  Tennessee  United States  Southern US   USCA  FUR-CH-4421
# 48508  Tennessee  United States  Southern US   USCA  FUR-CH-4419
#
#                                      Product Name Sub-Category   Category  \
# 48507  Global Push Button Manager's Chair, Indigo       Chairs  Furniture
# 48508                Global Low Back Tilter Chair       Chairs  Furniture
#
#          Sales  Quantity Discount    Profit Shipping Cost Order Priority
# ...

# %%
# len(name.split()) > 2
df_g[df_g['Customer Name'].str.split().str.len() > 2]["Customer Name"].drop_duplicates()
# Out:
# 675     Sample Company A
# 1723        Sue Ann Reed
# 2318       Paul Van Hugh
# 3482     Darrin Van Huff
# 3743       Mark Van Huff
# Name: Customer Name, dtype: object

# %% [markdown]
# ## What Happend with Corey-Lock?
# Since the Customer Corey-Lock doesn't have a Surname or Space (no clue how this is even possible) the Customer ID is containing a "Co" (for "Corey") instead of the initials (CL). As a result there a Customer ID for every combination of Country/Region.

# %%
#df_g['Customer Name'].drop_duplicates().sort_values()
print(df_g[~df_g['Customer Name'].str.contains(" ")][['Customer ID', 'Customer Name', "Country", "Region"]].drop_duplicates().sort_values(["Customer Name", "Country", "Region"]))
# for id, data in df_g[df_g['Customer Name'] == "Corey-Lock"].groupby("Customer ID"):
#     display(data[["Customer ID","Country", "Region"]].drop_duplicates())
# Out:
#         Customer ID Customer Name          Country             Region
# 2027      Co-126407    Corey-Lock        Australia            Oceania
# 5500     Co-1264018    Corey-Lock           Brazil      South America
# 7679     Co-1264027    Corey-Lock            China       Eastern Asia
# 11562     Co-264038    Corey-Lock            Egypt       North Africa
# 12509    Co-1264039    Corey-Lock      El Salvador    Central America
# 12833    Co-1264045    Corey-Lock           France     Western Europe
# 19544    Co-1264058    Corey-Lock            India      Southern Asia
# 24522    Co-1264066    Corey-Lock            Japan       Eastern Asia
# 26494    Co-1264082    Corey-Lock           Mexico    Central America
# 28489     Co-264086    Corey-Lock          Morocco       North Africa
# 28673    Co-1264088    Corey-Lock  Myanmar (Burma)  Southeastern Asia
# 29940    Co-1264093    Corey-Lock        Nicaragua    Central America
# ...

# %%
# CHECK IF Joe Lock 
display(df_g[~df_g['Customer Name'].str.contains(r'[a-z]$', regex=True)][["Customer ID", "Customer Name", "Country", "Region"]].drop_duplicates().sort_values(["Customer Name", "Country", "Region"]))
# for id, data in df_g[df_g['Customer Name'].str.contains("Joy Bell-")].groupby("Customer ID"):
#     print(data[["Customer ID", "Customer Name", "Country", "Region"]].drop_duplicates())
#     print("From:", min(data["Order Date"]), " / To:", max(data["Order Date"]))
# Out:
#         Customer ID     Customer Name                           Country  \
# 617       JF-152955    Jason Fortune-                         Argentina
# 2997      JF-152957    Jason Fortune-                         Australia
# 5910     JF-1529518    Jason Fortune-                            Brazil
# 6432      JF-529523    Jason Fortune-                            Canada
# 9231      JF-529530    Jason Fortune-                           Croatia
# 9450     JF-1529531    Jason Fortune-                              Cuba
# 10559    JF-1529536    Jason Fortune-                Dominican Republic
# 12330    JF-1529539    Jason Fortune-                       El Salvador
# 13727    JF-1529545    Jason Fortune-                            France
# 15516    JF-1529548    Jason Fortune-                           Germany
# 22201     JF-529560    Jason Fortune-                              Iran
# 23743    JF-1529564    Jason Fortune-                             Italy
# ...

# %%
# The last three digits of the Customer ID seems to be a ID for the "Country" / "Region"
#df_g[(df_g["Country"] == "Turkey") & (df_g["Region"] == "Western Asia")][["Customer ID", "Country", "Region", "Customer Name"]].drop_duplicates().sort_values(["Customer Name", "Country", "Region"])

# %%
df_g[df_g['Customer Name'].str.contains('Sample') | df_g['Customer Name'].str.contains('Test') | df_g['Customer Name'].str.contains('Test')]['Customer Name'].drop_duplicates()
# Out:
# 675    Sample Company A
# Name: Customer Name, dtype: object

# %% [markdown]
# ### How is the field Customer ID build?
# * `SS-208751406` (Customer Name: `Sung Shariari`)
# * `JF-1549082` (Somehow the CountryID for this Costa Rica should be 29 but it is only shown as a 2 at the end)
# * `[INITIALS]-[3-5DIGITS][3D Code of Country][1D Code for Region]`

# %%
# Let's generate the Initials on our own
# We need to take extra care for Names with more than words or just one word  
df_g['_Initials'] = df_g['Customer Name'].apply(lambda name: str((''.join(word[:1] for word in name.split()) if len(name.split()) > 1 else name)[0:2]))

# %%
# Create the DataFrame
data = {
    'Customer ID': ['SC-20050', 'SC-20050', 'CA-12055', 'BD-11605'],
    '_Initials': ['KR', 'KR', 'CA', 'BD']
}

dfX = pd.DataFrame(data)

display(dfX)
# Filter rows where Customer ID doesn't start with _Initials
#filtered_df = dfX[~dfX['Customer ID'].str.startswith(dfX['_Initials'])]
# Filter rows where Customer ID doesn't start with _Initials
filtered_df = dfX[dfX.apply(lambda row: not row['Customer ID'].startswith(row['_Initials']), axis=1)]

# Print the filtered DataFrame
print(filtered_df)
# Out:
#   Customer ID _Initials
# 0    SC-20050        KR
# 1    SC-20050        KR
# 2    CA-12055        CA
# 3    BD-11605        BD
#   Customer ID _Initials
# 0    SC-20050        KR
# 1    SC-20050        KR

# %%
# Check if Customer ID contains our generated Initials
filtered_df = df_g[df_g.apply(lambda row: not row['Customer ID'].startswith(row['_Initials']), axis=1)]
display(filtered_df)
# Out:
#        Row ID                 Order ID Order Date  Ship Date       Ship Mode  \
# 18659      33  US-2016-SC2005055-42514 2016-05-24 2016-05-31  Standard Class
# 18728      32  US-2016-SC2005055-42514 2016-05-24 2016-05-31  Standard Class
# 18759      28  US-2016-SC2005055-42514 2016-05-24 2016-05-31  Standard Class
# 18805      30  US-2016-SC2005055-42514 2016-05-24 2016-05-31  Standard Class
# 18919      34  US-2016-SC2005055-42514 2016-05-24 2016-05-31  Standard Class
# 18929      31  US-2016-SC2005055-42514 2016-05-24 2016-05-31  Standard Class
# 19008      29  US-2016-SC2005055-42514 2016-05-24 2016-05-31  Standard Class
#
#       Customer ID Customer Name      Segment  Postal Code         City  \
# 18659  SC-2005055       Kai Rey  Home Office          NaN  Tegucigalpa
# 18728  SC-2005055       Kai Rey  Home Office          NaN  Tegucigalpa
# 18759  SC-2005055       Kai Rey  Home Office          NaN  Tegucigalpa
# ...

# %%
# The last Digit of the Customer ID can be Region if there is more than one Region per Country
for country, data in df_g.groupby("Country"):
    if len(data["Region"].drop_duplicates()) > 1:
        print(country, data["Region"].drop_duplicates())
        #break
# => Only the USA seems to have more than 1 Region

#df_g[df_g["Region"] == "Southern US"][["Country", "Customer ID", "Order ID", "Order Date", "City"]].head().drop_duplicates().sort_values(["Country", "Order Date"])
# Out:
# United States 40553    Southern US
# 40614     Western US
# 43081     Eastern US
# 43857     Central US
# Name: Region, dtype: object

# %%
import warnings

# Let's remove the last digit if the Country is "United States"
df_g['_Region ID'] = df_g.apply(lambda row: int(row['Customer ID'][-1]) if row['Country'] == 'United States' else 0, axis=1)
df_g['Customer ID'] = df_g.apply(lambda row: row['Customer ID'][:-1] if row['Country'] == 'United States' else row['Customer ID'], axis=1)
display(df_g[df_g["Country"] == "United States"].head(2))
display(df_g[df_g["Country"] != "United States"].head(2))
print(df_g[df_g["Country"] == "United States"]["_Region ID"].value_counts())

if df_g[df_g["Country"] == "United States"]["_Region ID"].sum() != 47506:
    warnings.warn("The sum() of all RegionIDs should be 47506")
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 40553   33312  CA-2016-AM10705140-42632 2016-09-19 2016-09-24  Standard Class
# 40554   33310  CA-2016-AM10705140-42632 2016-09-19 2016-09-24  Standard Class
#
#        Customer ID   Customer Name   Segment  Postal Code    City    State  \
# 40553  AM-10705140  Anne McFarland  Consumer      36830.0  Auburn  Alabama
# 40554  AM-10705140  Anne McFarland  Consumer      36830.0  Auburn  Alabama
#
#              Country       Region Market   Product ID  \
# 40553  United States  Southern US   USCA  OFF-ST-6289
# 40554  United States  Southern US   USCA  FUR-CH-5431
#
#                                             Product Name Sub-Category  \
# 40553                        Tennsco Double-Tier Lockers      Storage
# 40554  Office Star - Professional Matrix Back Chair w...       Chairs
#
#               Category   Sales  Quantity Discount    Profit Shipping Cost  \
# ...

# %%
import re

prev_id = 0
out = ""

matching = {}
manual_matching = {
    "Bahrain": 10,
    "Belize": 82, # Matches Mexico (!)
    "Bhutan": 58, # Matches India (!)
    "Botswana": 117, # Matches South Africa (!)
    "Burkina Faso": 111, # Matches Senegal (1)
    "Burundi": 20,
    "Chad": 25,
    "Costa Rica": 28, # Matches Mexico (!)
    "Cyprus": 64, # Matches Italy (!!!)
    "Equatorial Guinea": 40,
    "Eritrea": 41,
    "French Guiana": 18, # Matches Brazil (!)
    "Greece": 148, # No zf found(!!!!!) / Must be added very late since it has the highest CountryID
    "Guadeloupe": 50,
    "Guyana": 54, # Matches Brazil (!)
    "Kuwait": 110, # Matches Saudi Arabia (!)
    "Laos": 144, # Matches Laos (1)
    "Luxembourg": 48, # Matches Germany (!)
    "Malawi": 87, # Matches Mozambique (!)
    "Montenegro": 85,
    "Oman": 110, # Matches Saudi Arabia (!)
    "Republic of the Congo": 106,
    "Serbia": 19, # Matches Bulgaria (!)
    "South Sudan": 119,
    "Suriname": 18, # Matches Brazil (!)
    "Tajikistan": 128, # [128]
    "The Gambia": 111, # Matches Senegal (!)
    "Western Sahara": 29, # No clue why western sahara has such a low CountryID
}

for country, data in df_g.groupby("Country"):
    #print(country)
    zf_found = False
    for i in reversed(range(1,5)):

        ids = (data['Customer ID'].str[-i:].drop_duplicates().astype("int").values)
        #print(i, prev_id, ids)

        # lets see if we can find the "0" and "5" before each countryID
        if (len(ids) == 2) and (abs(ids[0]-ids[-1]) in [50, 500, 5000]):
            zf_found = True


        if (zf_found == True) & (len(ids) == 1) & (int(ids[0]) not in matching):
            prev_id = int(ids[0])
            print("Found CountyID for", country, "=", prev_id)
            matching[country] = prev_id
            #display(data[["Row ID", "Customer ID", "Country"]].head())
            df_g.loc[df_g['Country'] == country, 'Customer ID'] = df_g.loc[df_g['Country'] == country, 'Customer ID'].str[:-i]
            break

    if country in manual_matching:
        print("Manual CountyID for", country, "=", manual_matching[country])
        matching[country] = manual_matching[country]
        df_g.loc[df_g['Country'] == country, 'Customer ID'] = df_g.loc[df_g['Country'] == country, 'Customer ID'].str[:-len(str(manual_matching[country]))]
    elif zf_found == False:
        print("Coudn't find a CountryID for", country)
        ids = (data['Customer ID'].str[-4:].drop_duplicates().astype("int").values)
        print(ids, len(ids))
        out = out + "\n" + '"' + country + '": ' + str(prev_id + 1) + ', # ' + ids[0]
print(out)
#display(matching)
# Out:
# Found CountyID for Afghanistan = 1
# Found CountyID for Albania = 2
# Found CountyID for Algeria = 3
# Found CountyID for Angola = 4
# Found CountyID for Argentina = 5
# Found CountyID for Armenia = 6
# Found CountyID for Australia = 7
# Found CountyID for Austria = 8
# Found CountyID for Azerbaijan = 9
# Manual CountyID for Bahrain = 10
# Found CountyID for Bangladesh = 11
# Found CountyID for Barbados = 12
# Found CountyID for Belarus = 13
# Found CountyID for Belgium = 14
# Manual CountyID for Belize = 82
# Found CountyID for Benin = 15
# Manual CountyID for Bhutan = 58
# Found CountyID for Bolivia = 16
# Found CountyID for Bosnia and Herzegovina = 17
# Manual CountyID for Botswana = 117
# Found CountyID for Brazil = 18
# Found CountyID for Bulgaria = 19
# Manual CountyID for Burkina Faso = 111
# Manual CountyID for Burundi = 20
# Found CountyID for Cambodia = 21
# Found CountyID for Cameroon = 22
# Found CountyID for Canada = 23
# Found CountyID for Central African Republic = 24
# ...

# %%
df_g["Order Priority"].drop_duplicates()
# Out:
# 0       Medium
# 5         High
# 12         Low
# 18    Critical
# Name: Order Priority, dtype: object

# %%
# Oh wow - the customers are sorted alphabetically and added 15 each times? WTF!!!
# And please beware that the entries for Greece got a 88888
df_g[["Customer Name", "Customer ID", "_Initials"]].sort_values(["Customer Name", "Customer ID"]).drop_duplicates().head(40)
# Out:
#               Customer Name Customer ID _Initials
# 730           Aaron Bergman    AB-10015        AB
# 6252          Aaron Bergman       AB-15        AB
# 725           Aaron Hawkins    AH-10030        AH
# 999          Aaron Smayling    AS-10045        AS
# 771         Adam Bellavance    AB-10060        AB
# 217               Adam Hart    AH-10075        AH
# 2185     Adam Shillingsburg    AS-10090        AS
# 641           Adrian Barton    AB-10105        AB
# 6598          Adrian Barton      AB-105        AB
# 1020            Adrian Hane    AH-10120        AH
# 11640           Adrian Hane      AH-120        AH
# 7018           Adrian Shami    AS-10135        AS
# 6359           Adrian Shami      AS-135        AS
# 1407            Aimee Bixby    AB-10150        AB
# 22144           Aimee Bixby      AB-150        AB
# 807             Alan Barnes    AB-10165        AB
# 6468            Alan Barnes      AB-165        AB
# 563          Alan Dominguez    AD-10180        AD
# ...

# %%
row_ids = []
for person, data in df_g[["Customer Name", "Customer ID", "_Initials", "Row ID"]].sort_values(["Customer Name", "Customer ID", "Row ID"]).groupby("Customer Name"):
    ids = data["Customer ID"].drop_duplicates().values
    #print(cleaned_ids, i)
    
    # Find the ID with the lower RowID and than search the max RowID for this CustomerID!!!
    if person == "Susan Vittorini":
        # I have no clue what happened with "Susan Vittorini" (for Row ID 31295) which is the only person where multiple IDs changes happend:
        # 321,6/22/2014,SV-2093555
        # [...]
        # 29801,9/21/2016,SV-209357
        # 31295,12/20/2017,SV-1093559
        # 31296,12/20/2017,SV-1093559
        # 33604,11/6/2017,SV-209351406
        # [...]
        # 39938,12/3/2017,SV-209351404
        # 43885,9/25/2015,SV-1093595
        continue
    elif len(ids) > 1:
        # Find the customer ID with the highest row ID
        max_row_id = data['Row ID'].max()
        highest_row_id_customer_id = data.loc[data['Row ID'] == max_row_id, 'Customer ID'].iloc[0]

        # Find the highest row ID for the customer ID with the lowest row ID
        lowest_row_id = data.loc[data['Customer ID'] == highest_row_id_customer_id, 'Row ID'].min()

        # print()
        # print(person)
        # print("Lowest Row ID Customer ID:", highest_row_id_customer_id)
        # print("Highest Row ID for Lowest Row ID Customer ID:", lowest_row_id)
        row_ids.append(lowest_row_id)
    #break
row_ids.sort()
print(row_ids)
print(min(row_ids))

changeRowID = min(row_ids)




# Check if there are any rowIDs that are larger than the changeRowID (just to be safe!)
for person, data in df_g[["Customer Name", "Customer ID", "_Initials", "Row ID"]].sort_values(["Customer Name", "Customer ID", "Row ID"]).groupby("Customer Name"):
    ids = data["Customer ID"].drop_duplicates().values

    if person == "Susan Vittorini":
        continue
    elif len(ids) > 1:
        min_row_id = data['Row ID'].min()
        lowest_row_id_customer_id = data.loc[data['Row ID'] == min_row_id, 'Customer ID'].iloc[0]

        # Find the highest row ID for the customer ID with the lowest row ID
        max_row_id = data.loc[data['Customer ID'] == lowest_row_id_customer_id, 'Row ID'].max()
        if max_row_id > changeRowID:
            print(person, max_row_id, ">", changeRowID)
# Out:
# [41291, 41294, 41296, 41298, 41300, 41302, 41304, 41307, 41308, 41310, 41311, 41314, 41315, 41316, 41320, 41331, 41332, 41333, 41336, 41337, 41338, 41340, 41342, 41346, 41348, 41352, 41356, 41357, 41358, 41359, 41361, 41365, 41367, 41368, 41370, 41371, 41372, 41375, 41376, 41377, 41378, 41379, 41380, 41384, 41385, 41386, 41388, 41391, 41392, 41393, 41396, 41397, 41398, 41400, 41404, 41406, 41407, 41408, 41409, 41410, 41412, 41415, 41417, 41419, 41424, 41425, 41426, 41432, 41433, 41435, 41437, 41438, 41439, 41440, 41442, 41443, 41445, 41446, 41447, 41448, 41449, 41450, 41451, 41459, 41460, 41463, 41465, 41466, 41467, 41473, 41474, 41476, 41479, 41481, 41482, 41483, 41484, 41486, 41487, 41488, 41493, 41497, 41499, 41503, 41506, 41507, 41508, 41510, 41512, 41513, 41514, 41518, 41519, 41520, 41522, 41525, 41528, 41529, 41533, 41535, 41536, 41540, 41542, 41543, 41544, 41546, 41549, 41550, 41561, 41563, 41564, 41565, 41569, 41576, 41578, 41581, 41582, 41583, 41586, 41587, 41590, 41594, 415
# ...

# %%
last_id = 0

# TODO The reason why there a sometimes multiple ids (i.e.:AG-270 and AG-10270) has something to do with the row ID? 
# Somewhere over the ID 40.000 the ID in Customer ID changes by 10.000 

for name, data in df_g.groupby("Customer Name"):
    
    temp_id = last_id + 15
    # if ( last_id < 1000 and temp_id > 1000):
    #     temp_id += 6000 # Please don't ask me why

    ids = (data['Customer ID'].str[3:].drop_duplicates().astype("int").values)
    ids = ids[~((ids == 88887) | (ids == 88888))]  # Just needed for "Aleksandra Gannaway" and "Denny Joy" in Greece

    
    if (len(ids) == 1) & (temp_id == ids[0]):
        # print("Treffer:", name, len(str(temp_id)), temp_id, ids)
        last_id = temp_id
    elif (len(ids) == 1) & (temp_id + 10000 == ids[0]):
        # print("Treffer:", name, len(str(temp_id)), temp_id, ids)
        last_id = temp_id
    elif name == "Kai Rey":
        # TODO No idea what happened here, but Kai Rey shares the same ID than the stupid Customer Name "Sample Company A"
        # Since Kai Rey also has the Initials "SC" (same as Sample Company A) I guess Kai Rey shoud be renamed "Sample Company A"
        print("WTF:", name, len(str(temp_id)), temp_id, ids)
        continue
    elif (len(ids) == 2) & (abs(ids[0] - ids[-1]) == 10000) & (wild_mode == True) & (ids.min() == temp_id):
        # print("Treffer:", name, len(str(temp_id)), temp_id, ids)
        last_id = temp_id
        #break
    else:
        print("Unknown:", name, len(str(temp_id)), temp_id, ids)
    #break
    #for country, data2 in data.group("Country"):
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14508\518178860.py in <module>
#      25         print("WTF:", name, len(str(temp_id)), temp_id, ids)
#      26         continue
# ---> 27     elif (len(ids) == 2) & (abs(ids[0] - ids[-1]) == 10000) & (wild_mode == True) & (ids.min() == temp_id):
#      28         # print("Treffer:", name, len(str(temp_id)), temp_id, ids)
#      29         last_id = temp_id
#
# NameError: name 'wild_mode' is not defined

# %%
last_id = 0
wild_mode = False

for name, data in df_g.groupby("Customer Name"):
    
    temp_id = last_id + 15
    if ( last_id < 1000 and temp_id > 1000):
        temp_id += 6000 # Please don't ask me why
    elif ( last_id < 10000 and temp_id > 10000):
        wild_mode = True    

    ids = (data['Customer ID'].str[-len(str(temp_id)):].drop_duplicates().astype("int").values)
    
    if (len(ids) == 1) & (temp_id == ids[0]):
        last_id = temp_id
    elif name == "Kai Rey":
        # TODO No idea what happened here, but Kai Rey shares the same ID than the stupid Customer Name "Sample Company A"
        # Since Kai Rey also has the Initials "SC" (same as Sample Company A) I guess Kai Rey shoud be renamed "Sample Company A"
        print(name, len(str(temp_id)), temp_id, ids)
        continue
    elif (len(ids) == 2) & (abs(ids[0] - ids[-1]) == 10000) & (wild_mode == True) & (ids.min() == temp_id):
        last_id = temp_id
        #break
    #break
    #for country, data2 in data.group("Country"):
# Out:
# Kai Rey 3 420 [50]

# %%
# We already removed RegionIDs for Unites States
# We already removed CountryID for all states
# Now we look for the last letter which is supposed to be a 0 or a 5
for country, data in df_g.groupby("Country"):
    ids = (data['Customer ID'].str[-1:].drop_duplicates().astype("int").values)
    ids = [num for num in ids if num != 0 and num != 5]
    if len(ids) > 0:
        print(country, ids)
# Out:
# Greece [7, 8]

# %% [markdown]
# ### How is the field Order ID build?
# * `IN-2017-CA120551-42816`
# * `[Country Code]-[Year]-[Customer ID]-[Days since 1899, 12, 30]`
#
# The part with the "days since 1899, 12, 30 is the way that Excel calculates the date internally.

# %%
# for date, data in df_g.groupby(["Order Date"]).sort_values('Order Date'):
#     print(date, len(data))

# Group the dataframe by 'Date' and count the occurrences
grouped_df = df_g.groupby('Order Date').size().reset_index(name='Count')

# Sort the dataframe by 'Date' in chronological order
sorted_df = grouped_df.sort_values('Order Date')

# Print the sorted dataframe
# print(sorted_df[sorted_df["Order Date"] > "2016-02-28"])
# print(sorted_df)

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
# for date, data in df_g.groupby(["Order Date"]).sort_values('Order Date'):
#     print(date, len(data))

# Group the dataframe by 'Date' and count the occurrences
grouped_df = df.groupby('Order Date').size().reset_index(name='Count')

# Sort the dataframe by 'Date' in chronological order
sorted_df = grouped_df.sort_values('Order Date')

# Print the sorted dataframe
# print(sorted_df)

# %%
#display(df_g[["Customer ID", "Order ID"]])

display(df_g[df_g.apply(lambda row: row['Customer ID'].replace('-', '') not in row['Order ID'], axis=1)][["Order ID", "Customer ID"]])

for c, data in (df_g[df_g.apply(lambda row: row['Customer ID'].replace('-', '') not in row['Order ID'], axis=1)].groupby(["Country"])):
    print(f"{c}: {len(data)} lines")

print("Are there any entries for Country 'United States' without a '140-' in the Order ID?") 
df_g[(df_g["Country"] == "United States") & ("140-" not in df_g["Order ID"].to_string())]

print("What are the numbers in the Order ID?")
df_g[(df_g["Country"] == "United States")]["Order ID"].head()

#display(df_g[(df_g['Customer_ID_Contained'] == False) & ("140-" in df_g["Order ID"].to_string()) & (df_g.Country != "United States")][["Order ID", "Customer ID", "Country"]])
# Out:
# Empty DataFrame
# Columns: [Order ID, Customer ID]
# Index: []
# Are there any entries for Country 'United States' without a '140-' in the Order ID?
# What are the numbers in the Order ID?
# 40553    CA-2016-AM10705140-42632
# 40554    CA-2016-AM10705140-42632
# 40555    CA-2016-AM10705140-42632
# 40556    CA-2017-KN16705140-42898
# 40557    CA-2015-MS17710140-42079
# Name: Order ID, dtype: object

# %%
print(df.shape)
print(df_g.shape) # + Market, Shipping Cost, Order Priority
# Out:
# (9994, 21)
# (51290, 26)

# %% [markdown]
# ## How are the ShippingCosts calculated?
# * 2 pieces cost 2.88 = 5,76
# * 3 pieces cost 1.85 = 5,55

# %%
# 32060,CA-2014-CS12250140-41653,1/14/2014,1/16/2014,Second Class,CS-122501408,Chris Selesnick,Corporate,71111,Bossier City,Louisiana,United States,Southern US,USCA,OFF-FA-6129,Staples,Fasteners,Office Supplies,"11,36",2,0,"5,3392","2,88",Critical
# 32063,CA-2014-CS12250140-41653,1/14/2014,1/16/2014,Second Class,CS-122501408,Chris Selesnick,Corporate,71111,Bossier City,Louisiana,United States,Southern US,USCA,OFF-FA-6129,Staples,Fasteners,Office Supplies,"5,64",3,0,"2,7072","1,85",Critical

# %% [markdown]
# ## Some Orders are duplicated due to different shipping costs (!!!)

# %%
i = 0
for key, data in df_g.groupby(["Order Date", 'Customer Name', "Product ID", "City"]):
    if len(data) > 1:
        print(key)
        display(data)
        i += 1
        if i > 10:
            break
# Out:
# (Timestamp('2014-01-14 00:00:00'), 'Chris Selesnick', 'OFF-FA-6129', 'Bossier City')
#        Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 44694   32060  CA-2014-CS12250140-41653 2014-01-14 2014-01-16  Second Class
# 44695   32063  CA-2014-CS12250140-41653 2014-01-14 2014-01-16  Second Class
#
#       Customer ID    Customer Name    Segment  Postal Code          City  \
# 44694    CS-12250  Chris Selesnick  Corporate      71111.0  Bossier City
# 44695    CS-12250  Chris Selesnick  Corporate      71111.0  Bossier City
#
#            State        Country       Region Market   Product ID Product Name  \
# 44694  Louisiana  United States  Southern US   USCA  OFF-FA-6129      Staples
# 44695  Louisiana  United States  Southern US   USCA  OFF-FA-6129      Staples
#
#       Sub-Category         Category  Sales  Quantity Discount  Profit  \
# 44694    Fasteners  Office Supplies  11,36         2        0  5,3392
# ...

# %%
# Select all columns except 'Row ID'
columns_to_check = df_g.columns.drop(['Row ID', 'Shipping Cost'])

# Check for duplicate rows based on selected columns
duplicates = df_g.duplicated(subset=columns_to_check, keep=False)

# Filter the dataframe to show only the duplicate rows
duplicate_rows = df_g[duplicates]

# Print the duplicate rows
display(duplicate_rows)
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 223     44647     AG-2017-CD27903-42967 2017-08-20 2017-08-25  Standard Class
# 231     44649     AG-2017-CD27903-42967 2017-08-20 2017-08-25  Standard Class
# 972     27443    ID-2014-AR105107-41761 2014-05-02 2014-05-08  Standard Class
# 973     27445    ID-2014-AR105107-41761 2014-05-02 2014-05-08  Standard Class
# 1170    27358    IN-2016-SF202007-42527 2016-06-06 2016-06-06        Same Day
# 1190    27357    IN-2016-SF202007-42527 2016-06-06 2016-06-06        Same Day
# 4295    13944   ES-2015-RF1984014-42245 2015-08-29 2015-09-05  Standard Class
# 4296    13946   ES-2015-RF1984014-42245 2015-08-29 2015-09-05  Standard Class
# 6756     8003   MX-2015-LS1720026-42341 2015-12-03 2015-12-07  Standard Class
# 6759     8007   MX-2015-LS1720026-42341 2015-12-03 2015-12-07  Standard Class
# 24802   49443    KE-2016-PC900069-42423 2016-02-23 2016-02-25    Second Class
# ...

# %%
display('|'.join(duplicate_rows["Order ID"].drop_duplicates().values))
# Out:
# 'AG-2017-CD27903-42967|ID-2014-AR105107-41761|IN-2016-SF202007-42527|ES-2015-RF1984014-42245|MX-2015-LS1720026-42341|KE-2016-PC900069-42423|ES-2016-SR20740120-42535|IN-2015-RM19375130-42313|US-2014-LB16795140-41751'

# %%
orders_df = df[['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID']]

# Splitting Products dataframe
products_df = df[['Product ID', 'Product Name', 'Sub-Category', 'Category']]

# Splitting Customers dataframe
customers_df = df[['Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City', 'State', 'Country', 'Region' ]]

# Print the first few rows of each dataframe (optional)
print("Orders dataframe:")
# print(orders_df.head())
# print(products_df.head())
# print(customers_df.head())
display(df.head())
# Out:
# Orders dataframe:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
customer = df["Customer ID", "Customer Name"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Coding\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# c:\Users\Coding\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\Coding\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Customer ID', 'Customer Name')
#
# The above exception was the direct cause of the following exception:
#
# ...
